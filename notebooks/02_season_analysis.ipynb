# %%
# ==============================
# IMPORT DES LIBRAIRIES
# ==============================

import pandas as pd
import matplotlib.pyplot as plt

# %%
# ==============================
# CHARGEMENT DU DATASET PRÉPARÉ
# ==============================
# On charge le dataset enrichi créé dans le notebook précédent

df = pd.read_csv("../data/processed/annecy_matches_features.csv", parse_dates=["Date"])

df.head()
# Out:
#         Date    Time        Round  Day Venue Result  GF  GA       Opponent  \
# 0 2025-08-09  20:00   Matchweek 1  Sat  Away      L   0   2         Pau FC
# 1 2025-08-16  14:00   Matchweek 2  Sat  Home      D   2   2  USL Dunkerque
# 2 2025-08-22  20:00   Matchweek 3  Fri  Away      W   1   0         Amiens
# 3 2025-08-29  20:00   Matchweek 4  Fri  Away      L   0   1       Red Star
# 4 2025-09-13  14:00   Matchweek 5  Sat  Home      D   1   1          Reims
#
#    Poss  ...      Captain Formation Opp Formation             Referee  \
# 0    42  ...  Ahmed Kashi     4-3-3       4-1-4-1  Tifenn Leprodhomme
# 1    37  ...  Ahmed Kashi     3-4-3       4-1-4-1   Faouzi Benchabane
# 2    35  ...  Ahmed Kashi     3-4-3         4-4-2     Geoffrey Kubler
# 3    62  ...  Ahmed Kashi     3-4-3       3-4-1-2       Mikael Lesage
# 4    32  ...  Ahmed Kashi     3-4-3       4-2-3-1     Mathieu Vernice
#
#   Goal_Diff  Points  Is_Home  Points_Cum  Goal_Diff_Cum  Matchweek
# 0        -2       0        0           0             -2          1
# 1         0       1        1           1             -2          2
# 2         1       3        0           4             -1          3
# 3        -1       0        0           4             -2          4
# 4         0       1        1           5             -2          5
#
# [5 rows x 21 columns]

# %%
# ==============================
# STATISTIQUES GÉNÉRALES
# ==============================

print("Matchs joués :", len(df))
print("Points totaux :", df["Points"].sum())
print("Buts marqués :", df["GF"].sum())
print("Buts encaissés :", df["GA"].sum())
print("Différence de buts :", df["Goal_Diff"].sum())
print("Possession moyenne :", round(df["Poss"].mean(), 2))
# Out:
# Matchs joués : 26
# Points totaux : 39
# Buts marqués : 34
# Buts encaissés : 28
# Différence de buts : 6
# Possession moyenne : 45.5

# %%
# ==============================
# RÉPARTITION DES RÉSULTATS
# ==============================

df["Result"].value_counts()
# Out:
# Result
# W    11
# L     9
# D     6
# Name: count, dtype: int64

# %%
# ==============================
# PERFORMANCE DOMICILE / EXTÉRIEUR
# ==============================

df.groupby("Venue")[["GF","GA","Points","Poss"]].mean()
# Out:
#              GF        GA    Points       Poss
# Venue
# Away   1.142857  1.214286  1.357143  44.285714
# Home   1.500000  0.916667  1.666667  46.916667

# %%
# ==============================
# ÉVOLUTION DES POINTS CUMULÉS
# ==============================

plt.figure(figsize=(10,5))

plt.plot(df["Matchweek"], df["Points_Cum"], marker="o")

plt.title("Évolution des points cumulés - Annecy")
plt.xlabel("Journée")
plt.ylabel("Points cumulés")

plt.grid(True)

plt.show()

# %%
# ==============================
# ÉVOLUTION DE LA DIFFÉRENCE DE BUTS
# ==============================

plt.figure(figsize=(10,5))

plt.plot(df["Matchweek"], df["Goal_Diff_Cum"], marker="o")

plt.title("Évolution de la différence de buts cumulée")
plt.xlabel("Journée")
plt.ylabel("Goal Difference cumulée")

plt.grid(True)

plt.show()
